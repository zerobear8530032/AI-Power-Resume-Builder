# %%
import pandas as pd

# %%
df= pd.read_csv("world-cities.csv");

# %%
hashset=set(df["country"])
sortedlist= list(hashset)
sortedlist.sort()
len(sortedlist)
# Out:
# 244

# %%
def validCharacter(name):
    for ch in name :
        asciich= ord(ch)
        if(not ((asciich>=ord('a') and asciich<=ord('z')) or (asciich>=ord('A') and asciich<=ord('Z')))):
            return False;
    return True;

# %%
def extractClearName(data):
    res=[]
    for name in data :
        if(validCharacter(name)):
            res.append(name);
    return res

# %%
clear_Country_Names= extractClearName(sortedlist)

# %%
len(cleaned_country_name)
# Out:
# 244

# %%
with open("country.txt", "w") as file:
    for row in cleaned_country_name:
        file.write(f'{{"value":"{row["value"]}","label":"{row["label"]}"}},\n')

# %%
df= pd.read_csv("topcities.csv");

# %%
df
# Out:
#      rank   Latitude   Longitude  Name of City       Country  2021 Population  \
# 0       1  35.682839  139.759455         Tokyo         Japan         37339804
# 1       2  28.651718   77.221939         Delhi         India         31181376
# 2       3  31.232276  121.469207      Shanghai         China         27795702
# 3       4 -23.550651  -46.633382     Sao Paulo        Brazil         22237472
# 4       5  19.432630  -99.133178   Mexico City        Mexico         21918936
# ..    ...        ...         ...           ...           ...              ...
# 995   996  29.290808  120.236651      Dongyang         China           578734
# 996   997  38.458398   47.931300       Ardabil          Iran           578222
# 997   998   8.756745   78.079753  Thoothukkudi         India           577945
# 998   999 -29.116395   26.215496  Bloemfontein  South Africa           577560
# 999  1000  22.427795  111.103268         Xinyi         China           577474
#
# ...

# %%
hashset=set(df["Name of City"])
sortedlist= list(hashset)
sortedlist.sort()
len(sortedlist)
# Out:
# 995

# %%
sortedlist
# Out:
# ['Aba',
#  'Abakaliki',
#  'Abidjan',
#  'Abomey-Calavi',
#  'Abu Dhabi',
#  'Abuja',
#  'Acapulco de Juarez',
#  'Accra',
#  'Ad-Dammam',
#  'Adana',
#  'Addis Ababa',
#  'Adelaide',
#  'Aden',
#  'Agadir',
#  'Agartala',
#  'Agra',
#  'Aguascalientes',
#  'Ahmedabad',
#  'Ahvaz',
#  'Ajmer',
#  'Akure',
#  'Al-Ain',
#  'Al-Hudaydah',
#  'Aleppo',
#  'Alexandria',
#  'Algiers',
#  'Aligarh',
#  'Allahabad',
#  'Almaty',
#  'Amara',
#  'Amman',
#  'Amravati',
#  'Amritsar',
#  'Amsterdam',
#  'Ankang',
#  'Ankara',
#  'Anqing',
#  'Anqiu',
#  'Ansan',
#  'Anshan',
#  'Anshun',
#  'Antalya',
#  'Antananarivo',
#  'Antipolo',
#  'Antwerp',
#  'Anyang',
#  'Ar-Rayyan',
#  'Aracaju',
#  'Ardabil',
#  'Arequipa',
#  'As-Suways',
#  'Asansol',
#  'Ashgabat',
#  'Asmara',
#  'Astana',
#  'Asuncion',
#  'Athens',
#  'Auckland',
#  'Aurangabad',
#  'Austin',
#  'Bacolod',
#  'Bacoor',
#  'Baghdad',
#  'Bahawalpur',
#  'Baishan',
#  'Baixada Santista',
#  'Baku',
#  'Bali',
#  'Bamako',
# ...

# %%
with open("city.txt", "w") as file:
    for city in sortedlist:
        file.write(f'{{"value":"{city}","label":"{city}"}},\n')

# %%
"Nigeria" in city
# Out:
# False
